# %%
import pandas as pd

# %%
df = pd.read_csv("Copper_Set.xlsx - Result 1.csv")
df
# Out:
# C:\Users\SVR\AppData\Local\Temp\ipykernel_12868\3869190636.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Copper_Set.xlsx - Result 1.csv")
#                                           id   item_date quantity tons  \
# 0       EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0     54.151139
# 1       4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0    768.024839
# 2       E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0    386.127949
# 3       F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0    202.411065
# 4       4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0    785.526262
# ...                                      ...         ...           ...
# 181668  DE633116-D1DF-4846-982E-55EFC3658A76  20200702.0   102.4824216
# 181669  A48374B1-E6DB-45F2-889A-1F9C27C099EB  20200702.0   208.0864686
# 181670  91643238-5C7B-4237-9A5F-63AE3D35F320  20200702.0   4.235593568
# ...

# %%
df = df.dropna(subset=['id'])
df = df.dropna(subset=['status'])

try:
    df=df.drop(['item_date'], axis=1)
    df=df.drop(['delivery date'], axis=1)
except:
    pass

# %%
df.columns.values
# Out:
# array(['id', 'quantity tons', 'customer', 'country', 'status',
#        'item type', 'application', 'thickness', 'width', 'material_ref',
#        'product_ref', 'selling_price'], dtype=object)

# %%
df['status'].unique()
# Out:
# array(['Won', 'Draft', 'To be approved', 'Lost', 'Not lost for AM',
#        'Wonderful', 'Revised', 'Offered', 'Offerable'], dtype=object)

# %%
it_types_list=[ 'Draft', 'To be approved',  'Not lost for AM',
       'Wonderful', 'Revised', 'Offered', 'Offerable']
for i in it_types_list:
    df=df[df['status'] != i]
df
# Out:
#                                           id quantity tons    customer  \
# 0       EC06F063-9DF0-440C-8764-0B0C05A4F6AE     54.151139  30156308.0
# 1       4E5F4B3D-DDDF-499D-AFDE-A3227EC49425    768.024839  30202938.0
# 2       E140FF1B-2407-4C02-A0DD-780A093B1158    386.127949  30153963.0
# 3       F8D507A0-9C62-4EFE-831E-33E1DA53BB50    202.411065  30349574.0
# 4       4E1C4E78-152B-430A-8094-ADD889C9D0AD    785.526262  30211560.0
# ...                                      ...           ...         ...
# 181668  DE633116-D1DF-4846-982E-55EFC3658A76   102.4824216  30200854.0
# 181669  A48374B1-E6DB-45F2-889A-1F9C27C099EB   208.0864686  30200854.0
# 181670  91643238-5C7B-4237-9A5F-63AE3D35F320   4.235593568  30200854.0
# 181671  7AFFD323-01D9-4E15-B80D-7D1B03498FC8         -2000  30200854.0
# 181672  AD0CA853-AE3C-4B2F-9FBB-8B0B965F84BC   406.6865384  30200854.0
#
#         country status item type  application  thickness   width  \
# ...

# %%
df['item type'].unique()
# Out:
# array(['W', 'S'], dtype=object)

# %%
for i in range(len(df['material_ref'])):
    df['material_ref'][i]=df['material_ref'][i].lsrtip('0')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[68], line 2
#       1 for i in range(len(df['material_ref'])):
# ----> 2     df['material_ref'][i]=df['material_ref'][i].lsrtip('0')
#
# AttributeError: 'str' object has no attribute 'lsrtip'
